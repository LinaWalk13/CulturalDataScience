# %% [markdown]
# # Lab 03: Fun with `pandas`!

# %% [markdown]
# Below are some exercises to get you working with `pandas` to manipulate data. As always, get as far as you can, and ask for help when you need it! Your teacher (me), you instructor, and your classmates are all here to help each other get better at coding. Getting the code to work is important, but do also take the time to make sure you understand what the commands are doing. This time, (with the exception of the Stroop challenge), all I've given you is the code to download the data. Then you are on your own. For the Stroop challenge, I gave the you code for the first step—after that, it's up to you :-)

# %% [markdown]
# ## Music sales challenge
#
# Write a script that:
#
# 1. Combines the tables of best-selling physical singles and best-selling digital singles on the Wikipedia page "List_of_best-selling_singles"
# 2. Adds a column which marks whether each row is from the list of physical singles or digital singles
# 3. Outputs the artist and single name for the year you were born. If there is no entry for that year, take the closest year after you were born.
# 4. Outputs the artist and single name for the year you were 15 years old.

# %%
# Starter code...

# %pip install pandas lxml beautifulsoup4 html5lib
import pandas as pd
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (2.2.2)
# Collecting lxml
#   Downloading lxml-5.3.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (4.12.3)
# Collecting html5lib
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: numpy>=1.22.4 in /opt/conda/lib/python3.10/site-packages (from pandas) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: six>=1.9 in /opt/conda/lib/python3.10/site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from html5lib) (0.5.1)
# Downloading lxml-5.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 26.7 MB/s eta 0:00:0000:01
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Installing collected packages: lxml, html5lib
# Successfully installed html5lib-1.1 lxml-5.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
rawdata = pd.read_html("https://en.wikipedia.org/wiki/List_of_best-selling_singles")

digital = rawdata[3]
physical = rawdata[0]

digital['Type']= 'digital'
physical['Type']= 'physical'
print(digital)
print(physical)
df_combined = pd.concat([digital, physical])
# Out:
#                                  Artist                      Single  Released  \
# 0                            Ed Sheeran              "Shape of You"      2017
# 1     Luis Fonsi featuring Daddy Yankee                 "Despacito"      2017
# 2               Rihanna featuring Drake                      "Work"      2016
# 3         The Chainsmokers and Coldplay  "Something Just Like This"      2017
# 4                            Ed Sheeran                   "Perfect"      2017
# 5    Wiz Khalifa featuring Charlie Puth             "See You Again"      2015
# 6     The Chainsmokers featuring Halsey                    "Closer"      2016
# 7                                 Adele       "Rolling in the Deep"      2011
# 8      Mark Ronson featuring Bruno Mars               "Uptown Funk"      2015
# 9                         Billie Eilish                   "Bad Guy"      2019
# 10                           Ed Sheeran         "Thinking Out Loud"      2015
# 11  Camila Cabello featuring Young Thug                    "Havana"      2017
# 12                            Lil Nas X             "Old Town Road"      2018
# 13                     Carly Rae Jepsen             "Call Me Maybe"      2011
# 14                         Taylor Swift                "Love Story"      2008
# 15                                Adele          "Someone Like You"      2011
# 16                              Rihanna                 "Needed Me"      2016
# 17      Shawn Mendes and Camila Cabello                  "Señorita"      2019
# 18                      Imagine Dragons               "Radioactive"      2012
# 19                      Imagine Dragons                  "Believer"      2017
# 20                                Drake                "God's Plan"      2018
#
#    Sales (in millions)        Source     Type
# 0              41.5[a]      [46][47]  digital
# 1              36.1[a]      [46][47]  digital
# 2              32.5[a]          [48]  digital
# 3              21.5[a]      [46][47]  digital
# 4              21.4[a]      [46][47]  digital
# 5              20.9[a]          [49]  digital
# 6              20.7[a]      [50][46]  digital
# 7                 20.6  [51][52][53]  digital
# 8                20[a]          [49]  digital
# 9              19.5[a]          [54]  digital
# 10             19.5[a]          [49]  digital
# 11             19.0[a]      [46][47]  digital
# 12             18.4[a]          [54]  digital
# 13                18.0          [55]  digital
# 14             18.0[a]          [56]  digital
# 15                17.0          [57]  digital
# 16             17.0[a]          [48]  digital
# 17             16.1[a]          [54]  digital
# 18               16[a]          [58]  digital
# 19             15.4[a]      [59][60]  digital
# 20             15.3[a]          [47]  digital
#                                   Artist  \
# 0                            Bing Crosby
# 1                             Elton John
# 2                            Bing Crosby
# 3                             Tino Rossi
# 4                Bill Haley & His Comets
# 5                        Whitney Houston
# 6                          Elvis Presley
# 7                         USA for Africa
# 8                          The Ink Spots
# 9                            Celine Dion
# 10                          Mariah Carey
# 11                               Baccara
# 12                           Bryan Adams
# 13  John Travolta and Olivia Newton-John
#
#                                                Single  Released  \
# 0                                   "White Christmas"      1942
# 1   "Something About the Way You Look Tonight"/"Ca...      1997
# 2                                      "Silent Night"      1935
# 3                                   "Petit Papa Noël"      1946
# 4                             "Rock Around the Clock"      1954
# 5                            "I Will Always Love You"      1992
# 6                                 "It's Now or Never"      1960
# 7                                  "We Are the World"      1985
# 8                                  "If I Didn't Care"      1939
# 9                               "My Heart Will Go On"      1997
# 10                  "All I Want For Christmas Is You"      1994
# 11                            "Yes Sir, I Can Boogie"      1977
# 12                "(Everything I Do) I Do It for You"      1991
# 13                       "You're the One That I Want"      1978
#
#        Sales (in millions)  Source      Type
# 0                       50     [1]  physical
# 1                       33     [1]  physical
# 2                       30     [2]  physical
# 3                       30     [3]  physical
# 4                       25  [4][5]  physical
# 5                       24     [6]  physical
# 6                       20  [7][8]  physical
# 7                       20     [9]  physical
# 8   19[disputed – discuss]    [10]  physical
# 9                       18    [11]  physical
# 10                      16    [12]  physical
# 11                      16    [13]  physical
# 12                      15    [14]  physical
# 13                      15    [15]  physical

# %%
# finging songs closest to my birthday
count = 0
for index, row in df_combined.iterrows():
    if row['Released'] == 2004:  
        print(row['Single'])  
        count = count + 1

if count == 0: 
    df_combined['Difference'] = abs(df_combined['Released']-2004)
    closest_number = df_combined['Difference'].idxmin()
    for index, row in df_combined.iterrows():
        if row['Difference'] == closest_number:  
            print(row['Single'])  
            print(row['Released'])
# Out:
# "Old Town Road"
# 2018
# "God's Plan"
# 2018

# %%
# finding songs fro years 2019 and 2020
for index, row in df_combined.iterrows():
    if row['Released'] == 2019 or row['Released'] == 2020:  
        print(row['Single'])
# Out:
# "Bad Guy"
# "Señorita"

# %% [markdown]
# ## Space challenge
#
# 1. Make a single dataframe that combines the space missions from the 1950's to the 2020's
# 2. Write a script that returns the year with the most launches
# 3. Write a script that returns the most common month for launches
# 4. Write a script that ranks the months from most launches to fewest launches

# %%
rawdata = pd.read_html("https://en.wikipedia.org/wiki/Timeline_of_Solar_System_exploration")

# connect dfs
df_combined = pd.concat(rawdata[0:9], ignore_index=True)

# remove unnessecary rows
df_cleaned = df_combined.dropna(subset=['Mission name', 'Launch date'])
# get years and get max from the newly defined 
years = df_cleaned['Launch date'].str[-5:]
pd.Series(years).value_counts().idxmax()

months = ['January - 31 days
February - 28 days in a common year and 29 days in leap years
March - 31 days
April - 30 days
May - 31 days
June - 30 days
July - 31 days
August - 31 days
September - 30 days
October - 31 days
November - 30 days
December - 31 days
# Out:
# ' 1965'

# %% [markdown]
# ## Supervillain challenge
#
# 1. Write a script that combines the tables showing supervillain debuts from the 30's through the 2010's
# 2. Write a script that ranks each decade in terms of how many supervillains debuted in that decade
# 3. Write a script that ranks the different comics companies in terms of how many supervillains they have, and display the results in a nice table (pandas dataframe)

# %%
rawdata = pd.read_html("http://en.wikipedia.org/wiki/List_of_comic_book_supervillain_debuts")
print(rawdata)
# Out:
# [    0                                                  1
# 0 NaN  This article has multiple issues. Please help ...
# 1 NaN  This article includes a list of general refere...
# 2 NaN  This article needs additional citations for ve...,     0                                                  1
# 0 NaN  This article includes a list of general refere...,     0                                                  1
# 0 NaN  This article needs additional citations for ve...,   Character / Team      Year Debuted                   Company  \
# 0   Ultra-Humanite       1939 (June)                        DC
# 1        Dr. Death       1939 (July)                        DC
# 2         The Monk  1939 (September)                        DC
# 3         The Claw   1939 (December)  Lev Gleason Publications
#
#                    Creator/s               First Appearance
# 0  Jerry Siegel, Joe Shuster     Action Comics (vol. 1) #13
# 1      Bob Kane, Bill Finger  Detective Comics (vol. 1) #29
# 2      Bob Kane, Bill Finger  Detective Comics (vol. 1) #31
# 3                  Jack Cole        Silver Streak Comics #1  ,                                Character / Team               Year Debuted  \
# 0                                      Hath-Set             1940 (January)
# 1                        Professor Hugo Strange            1940 (February)
# 2                                 Doctor Sivana            1940 (February)
# 3                                    Lex Luthor               1940 (April)
# 4                                     The Joker               1940 (April)
# 5                                      Catwoman               1940 (April)
# 6                                    Tony Zucco               1940 (April)
# 7                                      Clayface                1940 (June)
# 8                                     Scarecrow           1941 (September)
# 9                                          Ares             1941 (October)
# 10                                    Red Skull             1941 (October)
# 11                                  The Penguin            1941 (December)
# 12                                 Captain Nazi            1941 (December)
# 13                                         Ibac               1942 (March)
# 14                                  The Puzzler                1942 (June)
# 15                                     Two-Face              1942 (August)
# 16                                    Prankster              1942 (August)
# 17                                    The Shade           1942 (September)
# 18                                     Rag Doll            1942 (December)
# 19                                       Sabbac  (Fawcett) 1943; (DC) 2007
# 20  Mister Mind and the Monster Society of Evil                       1943
# 21                                    Brainwave            1943 (February)
# 22                       Tweedledum, Tweedledee               1943 (April)
# 23                                 Crime Doctor                1943 (July)
# 24                                       Toyman           1943 (September)
# 25                                      Cheetah           1943 (September)
# 26                                      Thinker             1943 (October)
# 27                                     Cavalier            1943 (November)
# 28                                Vandal Savage            1943 (December)
# 29                                      Gambler                       1944
# 30                                      Giganta                1944 (June)
# 31                                 Mr. Mxyzptlk           1944 (September)
# 32                               Solomon Grundy             1944 (October)
# 33                                      Monocle               1945 (April)
# 34                                       Turtle            1945 (December)
# 35                                   Black Adam            1945 (December)
# 36                                  Crazy Quilt                1946 (June)
# 37                                       Wizard               1947 (April)
# 38                              Penny Plunderer           1947 (September)
# 39                              Gentleman Ghost             1947 (October)
# 40                       Icicle (comics) (Joar)             1947 (October)
# 41                                  Rose, Thorn            1947 (November)
# 42                                  The Fiddler            1947 (December)
# 43                                Star Sapphire            1947 (December)
# 44                                   Mad Hatter             1948 (October)
# 45                                      Riddler             1948 (October)
# 46                                    The Rival            1949 (February)
#
#               Company                                          Creator/s  \
# 0                  DC                        Gardner Fox, Dennis Neville
# 1                  DC                              Bob Kane, Bill Finger
# 2   Fawcett Comics/DC                            Bill Parker, C. C. Beck
# 3                  DC                          Jerry Siegel, Joe Shuster
# 4                  DC              Bob Kane, Jerry Robinson, Bill Finger
# 5                  DC                              Bob Kane, Bill Finger
# 6                  DC              Bob Kane, Bill Finger, Jerry Robinson
# 7                  DC                              Bob Kane, Bill Finger
# 8                  DC                              Bill Finger, Bob Kane
# 9                  DC               William Moulton Marston, H. G. Peter
# 10      Marvel/Timely                              Joe Simon, Jack Kirby
# 11                 DC                              Bob Kane, Bill Finger
# 12  Fawcett Comics/DC                           Bill Woolfolk, Mac Raboy
# 13  Fawcett Comics/DC                            Otto Binder, C. C. Beck
# 14                 DC                                                NaN
# 15                 DC                              Bob Kane, Bill Finger
# 16                 DC                                                NaN
# 17                 DC                                        Gardner Fox
# 18                 DC                                        Gardner Fox
# 19  Fawcett Comics/DC  (Fawcett) Otto Binder, Al Carreno; (DC) Judd W...
# 20  Fawcett Comics/DC                            Otto Binder, C. C. Beck
# 21                 DC                                        Gardner Fox
# 22                 DC                                                NaN
# 23                 DC              Bill Finger, Bob Kane, George Roussos
# 24                 DC                          Jerry Siegel, Joe Shuster
# 25                 DC                            William Moulton Marston
# 26                 DC                         Gardner Fox, E. E. Hibbard
# 27                 DC                              Don Cameron, Bob Kane
# 28                 DC                       Alfred Bester, Martin Nodell
# 29                 DC                       Henry Kuttner, Martin Nodell
# 30                 DC                            William Moulton Marston
# 31                 DC                          Jerry Siegel, Joe Shuster
# 32                 DC                        Alfred Bester, Paul Reinman
# 33                 DC                            Gardner Fox, Joe Kubert
# 34                 DC                         Gardner Fox, Martin Naydel
# 35  Fawcett Comics/DC                           Otto Binder & C. C. Beck
# 36                 DC                                         Jack Kirby
# 37                 DC                           Gardner Fox, Irwin Hasen
# 38                 DC                                                NaN
# 39                 DC                        Robert Kanigher, Joe Kubert
# 40                 DC                       Robert Kanigher, Irwin Hasen
# 41                 DC                     John Broome, Carmine Infantino
# 42                 DC                         Robert Kanigher, Lee Elias
# 43                 DC                         Robert Kanigher, Lee Elias
# 44                 DC                              Bob Kane, Bill Finger
# 45                 DC                           Bill Finger, Dick Sprang
# 46                 DC                            John Broome, Joe Kubert
#
#                                      First Appearance
# 0                                     Flash Comics #1
# 1                       Detective Comics (vol. 1) #36
# 2                                      Whiz Comics #2
# 3                          Action Comics (vol. 1) #23
# 4                                  Batman (vol. 1) #1
# 5                                  Batman (vol. 1) #1
# 6                       Detective Comics (vol. 1) #38
# 7                       Detective Comics (vol. 1) #40
# 8                            World's Finest Comics #3
# 9                                     Wonder Woman #1
# 10                          Captain America Comics #1
# 11                      Detective Comics (vol. 1) #58
# 12                                  Master Comics #21
# 13                       Captain Marvel Adventures #8
# 14                         Action Comics (vol. 1) #49
# 15                      Detective Comics (vol. 1) #66
# 16                         Action Comics (vol. 1) #51
# 17                                   Flash Comics #33
# 18                                   Flash Comics #36
# 19  (Fawcett) Captain Marvel, Jr. #4; (DC) Outside...
# 20                      Captain Marvel Adventures #22
# 21                                       All Star #15
# 22                      Detective Comics (vol. 1) #74
# 23                      Detective Comics (vol. 1) #77
# 24                         Action Comics (vol. 1) #64
# 25                           Wonder Woman (vol. 1) #6
# 26                                      All-Flash #12
# 27                      Detective Comics (vol. 1) #81
# 28                         Green Lantern (vol. 1) #10
# 29                         Green Lantern (vol. 1) #12
# 30                           Wonder Woman (vol. 1) #9
# 31                              Superman (vol. 1) #30
# 32                            All-American Comics #61
# 33                                   Flash Comics #64
# 34                                       All-Star #21
# 35                               The Marvel Family #1
# 36                                  Boy Commandos #15
# 37                                All Star Comics #34
# 38                          World's Finest Comics #30
# 39                                   Flash Comics #88
# 40                            All American Comics #90
# 41                                   Flash Comics #89
# 42                                      All-Flash #32
# 43                                      All-Flash #32
# 44                                Batman (vol. 1) #49
# 45                     Detective Comics (vol. 1) #140
# 46                                  Flash Comics #104  ,                                      Character / Team      Year Debuted  \
# 0                                            Deadshot       1950 (June)
# 1                                           The Mekon              1950
# 2                                            Red Hood   1951 (February)
# 3                                         Killer Moth   1951 (February)
# 4                                             Firefly       1952 (June)
# 5                                         Gorilla-Man              1954
# 6                                       Morgan le Fay              1955
# 7                                     The Yellow Claw              1956
# 8                                        Captain Cold        1957 (May)
# 9                                Doctor Achilles Milo  1957 (September)
# 10                                          Signalman   1957 (December)
# 11                                           Brainiac       1958 (July)
# 12                                            Bizarro    1958 (October)
# 13    Terrible Trio (DC Comics) (Fox, Shark, Vulture)      1958 (March)
# 14                                       Calendar Man  1958 (September)
# 15                                    Doctor Double X   1958 (November)
# 16                                             Titano   1959 (February)
# 17                   Mr. Freeze (originally Mr. Zero)   1959 (February)
# 18         Doctor Alchemy (originally as Mr. Element)      1959 (March)
# 19                                      Mirror Master      1959 (March)
# 20                                      Gorilla Grodd      1959 (April)
# 21                                            Metallo        1959 (May)
# 22                                         Pied Piper        1959 (May)
# 23                                   Molten Man-Thing  1959 (September)
# 24  Suicide Squad (Rick Flag Jr., Jess Bright, Dr....  1959 (September)
# 25                                     Weather Wizard   1959 (December)
#
#           Company                                Creator/s  \
# 0              DC  Bob Kane, David Vern Reed, Lew Schwartz
# 1             NaN                            Frank Hampson
# 2              DC                                      NaN
# 3              DC                                      NaN
# 4              DC               France Herron, Dick Sprang
# 5   Marvel/Timely                               Bob Powell
# 6   Marvel/Timely                    Stan Lee, Joe Maneely
# 7   Marvel/Timely                Al Feldstein, Joe Maneely
# 8              DC           John Broome, Carmine Infantino
# 9              DC                                      NaN
# 10             DC                                      NaN
# 11             DC                     Curt Swan, Stan Kaye
# 12             DC                 Otto Binder, George Papp
# 13             DC               Dave Wood, Sheldon Moldoff
# 14             DC                              Bill Finger
# 15             DC                                      NaN
# 16             DC                                      NaN
# 17             DC                                 Bob Kane
# 18             DC           John Broome, Carmine Infantino
# 19             DC           John Broome, Carmine Infantino
# 20             DC           John Broome, Carmine Infantino
# 21             DC            Robert Bernstein, Al Plastino
# 22             DC           John Broome, Carmine Infantino
# 23         Marvel        Stan Lee, Jack Kirby, Steve Ditko
# 24             DC              Robert Kanigher, Ross Andru
# 25             DC           John Broome, Carmine Infantino
#
#                        First Appearance
# 0                   Batman (vol. 1) #59
# 1         Dan Dare, Pilot of the Future
# 2                 Detective Comics #168
# 3                            Batman #63
# 4                 Detective Comics #184
# 5                     Mystery Tales #21
# 6                Black Knight comics #1
# 7                 Yellow Claw comics #1
# 8                           Showcase #8
# 9                 Detective Comics #247
# 10                          Batman #112
# 11          Action Comics (vol. 1) #242
# 12                Superboy (vol. 1) #68
# 13       Detective Comics (vol. 1) #253
# 14       Detective Comics (vol. 1) #259
# 15       Detective Comics (vol. 1) #261
# 16               Superman (vol. 1) #127
# 17                 Batman (vol. 1) #121
# 18                         Showcase #19
# 19              The Flash (vol. 1) #105
# 20              The Flash (vol. 1) #106
# 21          Action Comics (vol. 1) #252
# 22              The Flash (vol. 1) #106
# 23                 Tales of Suspense #7
# 24  The Brave and the Bold (vol. 1) #25
# 25              The Flash (vol. 1) #110  ,     Character / Team     Year Debuted Company                       Creator/s  \
# 0             Grottu  1960 (February)  Marvel        Jack Kirby, Bill Everett
# 1             Starro  1960 (February)      DC                     Gardner Fox
# 2              Amazo      1960 (June)      DC                     Gardner Fox
# 3      Professor Ivo      1960 (June)      DC      Gardner Fox, Mike Sekowsky
# 4          Trickster      1960 (June)      DC  John Broome, Carmine Infantino
# ..               ...              ...     ...                             ...
# 223         Hyperion  1969 (November)  Marvel         Roy Thomas, Sal Buscema
# 224      The Fat Man             1969      DC                      Neal Adams
# 225             Naga             1969  Marvel       Roy Thomas, Marie Severin
# 226              Set             1969  Marvel                      Roy Thomas
# 227            Viper             1969  Marvel                    Jim Steranko
#
#                         First Appearance
# 0                      Strange Tales #73
# 1    The Brave and the Bold (vol. 1) #28
# 2    The Brave and the Bold (vol. 1) #30
# 3    The Brave and the Bold (vol. 1) #30
# 4                The Flash (vol. 1) #113
# ..                                   ...
# 223                  Avengers vol. 1 #70
# 224               Teen Titans vol. 1 #20
# 225                       Sub-Mariner #9
# 226                       Sub-Mariner #9
# 227          Captain America vol. 1 #110
#
# [228 rows x 5 columns],            Character / Team    Year Debuted Company  \
# 0           Agatha Harkness  1970 (January)  Marvel
# 1                     Arkon    1970 (April)  Marvel
# 2                   Man-Bat     1970 (June)      DC
# 3             Lethal Legion     1970 (July)  Marvel
# 4   Intergang (Morgan Edge)  1970 (October)      DC
# ..                      ...             ...     ...
# 92                    Letha            1979  Marvel
# 82   Geoff Johns, Lee Moder                           Stars and S.T.R.I.P.E #1
# 83                      NaN                               Batman: Dark Victory
#
# [84 rows x 5 columns],        Character / Team     Year Debuted Company  \
# 0            Kyle Abbot             2000      DC
# 1            Able Crown             2000      DC
# 2              Agamemno             2000      DC
# 3                  Orca             2000      DC
# 4                 Zeiss             2000      DC
# 5              Mortalla             2000      DC
# 6       Queen of Fables             2000      DC
# 7                  Nero             2001      DC
# 8   Black, White Bandit             2001      DC
# 9            Blacksmith             2001      DC
# 10          Double Down             2001      DC
# 11               Girder             2001      DC
# 12               Murmur             2001      DC
# 13               Cicada             2001      DC
# 14          Onimar Synn             2001      DC
# 15              Tar Pit             2001      DC
# 16   Monsieur Stigmonus             2001      DC
# 17     Manchester Black             2001      DC
# 18               Mongal             2001      DC
# 19               Morlun      2001 (June)  Marvel
# 20       Cassandra Nova      2001 (July)  Marvel
# 21             Imperiex             2001      DC
# 22                 Zoom             2001      DC
# 23           Peek-a-Boo             2002      DC
# 24               Scorch             2002      DC
# 25            Mortician             2002      DC
# 26               Savant    2003 (August)      DC
# 27                 Hush             2003      DC
# 28             Al-Tariq             2003  Marvel
# 29          Great White             2003      DC
# 30                 Kira             2003     NaN
# 31                Equus             2004      DC
# 32          Owen Mercer             2004      DC
# 33                Preus             2004      DC
# 34                  Ord             2004  Marvel
# 35      Rainbow Raiders             2005      DC
# 36             Batzarro             2005      DC
# 37            Parademon             2005      DC
# 38       Marvel Zombies             2005  Marvel
# 39     Amatsu-Mikaboshi  2006 (February)  Marvel
# 40             Livewire             2006      DC
# 41            Tally Man             2006      DC
# 42              Arkillo       2006 (May)      DC
# 43                Talon             2006      DC
# 44               Facade             2006      DC
# 45            Atrocitus  2007 (December)      DC
# 46            Larfleeze  2007 (December)      DC
# 47               Menace             2008  Marvel
# 48            Beth Kane    2009 (August)      DC
#
#                                             Creator/s  \
# 0                                          Greg Rucka
# 1                                                 NaN
# 2                                                 NaN
# 3                                          Larry Hama
# 4                         Ed Brubaker, Scott McDaniel
# 5                                       Walt Simonson
# 6                              Mark Waid, Gail Simone
# 7              Judd Winick, Darryl Banks, Mark Bright
# 8                                        Dave Gibbons
# 9                       Geoff Johns, Ethan Van Sciver
# 10                      Geoff Johns, Ethan Van Sciver
# 11                      Geoff Johns, Ethan Van Sciver
# 12                      Geoff Johns, Ethan Van Sciver
# 13                         Geoff Johns, Scott Kollins
# 14                        David S. Goyer, Geoff Johns
# 15                         Geoff Johns, Scott Kollins
# 16                         J. M. DeMatteis, Ryan Sook
# 17                             Joe Kelly, Doug Mahnke
# 18                                                NaN
# 19           J. Michael Straczynski, John Romita, Jr.
# 20                      Grant Morrison, Frank Quitely
# 21                                                NaN
# 22                          Geoff Johns, Scott Kolins
# 23                          Geoff Johns, Scott Kolins
# 24                                                NaN
# 25                      Devin Grayson, Roger Robinson
# 26                              Gail Simone, Ed Benes
# 27                                 Jeph Loeb, Jim Lee
# 28                                                NaN
# 2                                        Jason Aaron
# 3                                      Rhode Montijo
# 4                                   Brian Buccellato
# 5         Joshua Williamson, Carmine Di Giandomenico
# 6                                      Rhode Montijo
# 7                                      Rhode Montijo
# 8                                      Rhode Montijo
#
#                                     First Appearance
# 0                                         Titans #28
# 1                             Green Arrow (vol.5) #0
# 2                            Thor: God of Thunder #1
# 3  The Gumazing Gum Girl! Book 1: Chews Your Destiny
# 4                                      The Flash #28
# 5                              The Flash: Rebirth #1
# 6            The Gumazing Gum Girl! Book 2: Gum Luck
# 7        The Gumazing Gum Girl! Book 4: Cover Blown!
# 8        The Gumazing Gum Girl! Book 4: Cover Blown!  ]

# %% [markdown]
# ## Stroop challenge
#
# Every year between 2015 and 2021, the students in my Language, Cognition, and the Brain course participated in a version of the Stroop task. Using a stopwatch (ok, using their phones), they recorded how fast they could say a list of things (either reading or naming colors or color words). The column names mean "Reading with No Interference", "Naming with Interference", "Naming with No Interference", and "Reading with Interference". The times are in seconds.
#
# ### Stroop challenge 1:
# Transform these data from wide format to long format, so that the result is a dataframe with
# - 1 column named "Participant_id" with a unique number for each participant (you can use the row indices)
# - 1 column named "Year" with the year data
# - 1 column named "Task" that shows which task they were doing
# - 1 column named "RT" that shows their response time

# %%
# Starter code 1...

df = pd.read_csv("https://raw.githubusercontent.com/ethanweed/Stroop/master/Stroop-raw-over-the-years.csv")
df.head()
# Out:
#    Reading_NoInt  Naming_Int  Naming_NoInt  Reading_Int  Year
# 0           4.16        6.76          4.45         4.65  2015
# 1           4.35        7.73          4.78         4.46  2015
# 2           3.60        7.00          4.00         3.50  2015
# 3           3.90        9.03          4.60         6.30  2015
# 4           4.22        9.98          6.83         6.24  2015

# %%
# Starter code 2...

# Make a new column using the dataframe indices as particpant numbers

df.index.name = 'Participant_id'
df = df.reset_index()

#df.reset_index(inplace = True)
# NOTE: This line does exactly the same thing as the line above:
# it replaces the original df with a new df with the updated index. That's what
# "inplace = True" means. Or, you can just assign the dataframe with the updated index
# to a new dataframe with the same name as the old dataframe, which is what I did above.
# The end result is the same.

df
# Out:
#      Participant_id  Reading_NoInt  Naming_Int  Naming_NoInt  Reading_Int  \
# 0                 0           4.16        6.76          4.45         4.65
# 1                 1           4.35        7.73          4.78         4.46
# 2                 2           3.60        7.00          4.00         3.50
# 3                 3           3.90        9.03          4.60         6.30
# 4                 4           4.22        9.98          6.83         6.24
# ..              ...            ...         ...           ...          ...
# 177             177           4.30        7.08          6.25         4.28
# 178             178           4.75        9.66          6.12         5.49
# 179             179           4.98        7.52          6.73         5.16
# 180             180           5.16        8.81          8.19         5.51
# 181             181           4.27       10.40          5.32         4.59
#
#      Year
# 0    2015
# 1    2015
# 2    2015
# 3    2015
# 4    2015
# ..    ...
# 177  2021
# 178  2021
# 179  2021
# 180  2021
# 181  2021
#
# [182 rows x 6 columns]

# %% [markdown]
# ## Stroop challenge 2 (Advanced!!!):
#
# Make a new dataframe which shows the mean response time (in seconds) for each task for each year.
